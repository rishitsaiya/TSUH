# %%
import torch
import torchvision
# !pip install torchprof
import torchprof
import torchvision.models as models
from torch.profiler import profile, record_function, ProfilerActivity
from torchsummary import summary
# Out:
# Requirement already satisfied: torchprof in /usr/local/lib/python3.7/dist-packages (1.4.0)
# Requirement already satisfied: torch<1.9,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from torchprof) (1.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<1.9,>=1.1.0->torchprof) (3.10.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch<1.9,>=1.1.0->torchprof) (1.19.5)

# %%
# model = models.alexnet(pretrained=True)
# inputs = torch.rand([1, 3, 224, 224])
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]

# %%
#model = models.googlenet(pretrained=True) 
#inputs = torch.rand([1, 3, 224, 224])
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
model = models.mobilenet_v2(pretrained=True)
inputs = torch.rand([1, 3, 224, 224])
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
#   0%|          | 0.00/13.6M [00:00<?, ?B/s]

# %%
#model = models.resnet18()
#inputs = torch.rand([1, 3, 224, 224])

# %%
#model = models.squeezenet1_0(pretrained=True)
#inputs = torch.rand([1, 3, 224, 224])
# Out:
# Downloading: "https://download.pytorch.org/models/squeezenet1_0-b66bff10.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_0-b66bff10.pth
#   0%|          | 0.00/4.78M [00:00<?, ?B/s]

# %%
#model = models.vgg16(pretrained=True)
#inputs = torch.rand([1, 3, 224, 224])
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
print(model)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
summary(model,(3,224,224))
# summary(model(229,229))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#              ReLU6-6         [-1, 32, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             512
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#   InvertedResidual-9         [-1, 16, 112, 112]               0
#            Conv2d-10         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-11         [-1, 96, 112, 112]             192
#             ReLU6-12         [-1, 96, 112, 112]               0
#            Conv2d-13           [-1, 96, 56, 56]             864
#       BatchNorm2d-14           [-1, 96, 56, 56]             192
#             ReLU6-15           [-1, 96, 56, 56]               0
#            Conv2d-16           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-17           [-1, 24, 56, 56]              48
#  InvertedResidual-18           [-1, 24, 56, 56]               0
#            Conv2d-19          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-20          [-1, 144, 56, 56]             288
#             ReLU6-21          [-1, 144, 56, 56]               0
#            Conv2d-22          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-23          [-1, 144, 56, 56]             288
#             ReLU6-24          [-1, 144, 56, 56]               0
#            Conv2d-25           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-26           [-1, 24, 56, 56]              48
#  InvertedResidual-27           [-1, 24, 56, 56]               0
#            Conv2d-28          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-29          [-1, 144, 56, 56]             288
#             ReLU6-30          [-1, 144, 56, 56]               0
#            Conv2d-31          [-1, 144, 28, 28]           1,296
#       BatchNorm2d-32          [-1, 144, 28, 28]             288
#             ReLU6-33          [-1, 144, 28, 28]               0
#            Conv2d-34           [-1, 32, 28, 28]           4,608
#       BatchNorm2d-35           [-1, 32, 28, 28]              64
#  InvertedResidual-36           [-1, 32, 28, 28]               0
#            Conv2d-37          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-38          [-1, 192, 28, 28]             384
#             ReLU6-39          [-1, 192, 28, 28]               0
#            Conv2d-40          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-41          [-1, 192, 28, 28]             384
#             ReLU6-42          [-1, 192, 28, 28]               0
#            Conv2d-43           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-44           [-1, 32, 28, 28]              64
#  InvertedResidual-45           [-1, 32, 28, 28]               0
#            Conv2d-46          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-47          [-1, 192, 28, 28]             384
#             ReLU6-48          [-1, 192, 28, 28]               0
#            Conv2d-49          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-50          [-1, 192, 28, 28]             384
#             ReLU6-51          [-1, 192, 28, 28]               0
#            Conv2d-52           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-53           [-1, 32, 28, 28]              64
#  InvertedResidual-54           [-1, 32, 28, 28]               0
#            Conv2d-55          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-56          [-1, 192, 28, 28]             384
#             ReLU6-57          [-1, 192, 28, 28]               0
#            Conv2d-58          [-1, 192, 14, 14]           1,728
#       BatchNorm2d-59          [-1, 192, 14, 14]             384
#             ReLU6-60          [-1, 192, 14, 14]               0
#            Conv2d-61           [-1, 64, 14, 14]          12,288
#       BatchNorm2d-62           [-1, 64, 14, 14]             128
#  InvertedResidual-63           [-1, 64, 14, 14]               0
#            Conv2d-64          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-65          [-1, 384, 14, 14]             768
#             ReLU6-66          [-1, 384, 14, 14]               0
#            Conv2d-67          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-68          [-1, 384, 14, 14]             768
#             ReLU6-69          [-1, 384, 14, 14]               0
#            Conv2d-70           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-71           [-1, 64, 14, 14]             128
#  InvertedResidual-72           [-1, 64, 14, 14]               0
#            Conv2d-73          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-74          [-1, 384, 14, 14]             768
#             ReLU6-75          [-1, 384, 14, 14]               0
#            Conv2d-76          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-77          [-1, 384, 14, 14]             768
#             ReLU6-78          [-1, 384, 14, 14]               0
#            Conv2d-79           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-80           [-1, 64, 14, 14]             128
#  InvertedResidual-81           [-1, 64, 14, 14]               0
#            Conv2d-82          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-83          [-1, 384, 14, 14]             768
#             ReLU6-84          [-1, 384, 14, 14]               0
#            Conv2d-85          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-86          [-1, 384, 14, 14]             768
#             ReLU6-87          [-1, 384, 14, 14]               0
#            Conv2d-88           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-89           [-1, 64, 14, 14]             128
#  InvertedResidual-90           [-1, 64, 14, 14]               0
#            Conv2d-91          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-92          [-1, 384, 14, 14]             768
#             ReLU6-93          [-1, 384, 14, 14]               0
#            Conv2d-94          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-95          [-1, 384, 14, 14]             768
#             ReLU6-96          [-1, 384, 14, 14]               0
#            Conv2d-97           [-1, 96, 14, 14]          36,864
#       BatchNorm2d-98           [-1, 96, 14, 14]             192
#  InvertedResidual-99           [-1, 96, 14, 14]               0
#           Conv2d-100          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-101          [-1, 576, 14, 14]           1,152
#            ReLU6-102          [-1, 576, 14, 14]               0
#           Conv2d-103          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-104          [-1, 576, 14, 14]           1,152
#            ReLU6-105          [-1, 576, 14, 14]               0
#           Conv2d-106           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-107           [-1, 96, 14, 14]             192
# InvertedResidual-108           [-1, 96, 14, 14]               0
#           Conv2d-109          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-110          [-1, 576, 14, 14]           1,152
#            ReLU6-111          [-1, 576, 14, 14]               0
#           Conv2d-112          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-113          [-1, 576, 14, 14]           1,152
#            ReLU6-114          [-1, 576, 14, 14]               0
#           Conv2d-115           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-116           [-1, 96, 14, 14]             192
# InvertedResidual-117           [-1, 96, 14, 14]               0
#           Conv2d-118          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-119          [-1, 576, 14, 14]           1,152
#            ReLU6-120          [-1, 576, 14, 14]               0
#           Conv2d-121            [-1, 576, 7, 7]           5,184
#      BatchNorm2d-122            [-1, 576, 7, 7]           1,152
#            ReLU6-123            [-1, 576, 7, 7]               0
#           Conv2d-124            [-1, 160, 7, 7]          92,160
#      BatchNorm2d-125            [-1, 160, 7, 7]             320
# InvertedResidual-126            [-1, 160, 7, 7]               0
#           Conv2d-127            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-128            [-1, 960, 7, 7]           1,920
#            ReLU6-129            [-1, 960, 7, 7]               0
#           Conv2d-130            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-131            [-1, 960, 7, 7]           1,920
#            ReLU6-132            [-1, 960, 7, 7]               0
#           Conv2d-133            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-134            [-1, 160, 7, 7]             320
# InvertedResidual-135            [-1, 160, 7, 7]               0
#           Conv2d-136            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-137            [-1, 960, 7, 7]           1,920
#            ReLU6-138            [-1, 960, 7, 7]               0
#           Conv2d-139            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-140            [-1, 960, 7, 7]           1,920
#            ReLU6-141            [-1, 960, 7, 7]               0
#           Conv2d-142            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-143            [-1, 160, 7, 7]             320
# InvertedResidual-144            [-1, 160, 7, 7]               0
#           Conv2d-145            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-146            [-1, 960, 7, 7]           1,920
#            ReLU6-147            [-1, 960, 7, 7]               0
#           Conv2d-148            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-149            [-1, 960, 7, 7]           1,920
#            ReLU6-150            [-1, 960, 7, 7]               0
#           Conv2d-151            [-1, 320, 7, 7]         307,200
#      BatchNorm2d-152            [-1, 320, 7, 7]             640
# InvertedResidual-153            [-1, 320, 7, 7]               0
#           Conv2d-154           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-155           [-1, 1280, 7, 7]           2,560
#            ReLU6-156           [-1, 1280, 7, 7]               0
#          Dropout-157                 [-1, 1280]               0
#           Linear-158                 [-1, 1000]       1,281,000
# ================================================================
# Total params: 3,504,872
# Trainable params: 3,504,872
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 152.87
# Params size (MB): 13.37
# Estimated Total Size (MB): 166.81
# ----------------------------------------------------------------

# %%
# with profile(activities=[ProfilerActivity.CPU], record_shapes=True) as prof:
#     with record_function("model_inference"):
#         model(inputs)
# with torch.autograd.profiler.profile() as prof:
#     model(inputs)
# print(prof)
with torchprof.Profile(model) as prof:
    model(inputs)

# equivalent to `print(prof)` and `print(prof.display())`
print(prof.display(show_events=True))
# Out:
# Module                                | Self CPU total | CPU total | Number of Calls
# --------------------------------------|----------------|-----------|----------------
# MobileNetV2                           |                |           |
# ├── features                          |                |           |
# │├── 0                                |                |           |
# ││├── 0                               |                |           |
# │││├── aten::conv2d                   | 9.165us        | 2.018ms   | 1
# │││├── aten::convolution              | 6.742us        | 2.009ms   | 1
# │││├── aten::_convolution             | 25.139us       | 2.002ms   | 1
# │││├── aten::mkldnn_convolution       | 1.919ms        | 1.977ms   | 1
# │││├── aten::empty                    | 50.924us       | 50.924us  | 1
# │││└── aten::as_strided_              | 7.095us        | 7.095us   | 1
# ││├── 1                               |                |           |
# │││├── aten::add                      | 62.331us       | 62.331us  | 1
# │││├── aten::batch_norm               | 8.848us        | 7.538ms   | 1
# │││├── aten::_batch_norm_impl_index   | 16.233us       | 7.529ms   | 1
# │││├── aten::empty                    | 11.482us       | 11.482us  | 4
# │││├── aten::native_batch_norm        | 7.234ms        | 7.511ms   | 1
# │││├── aten::select                   | 159.408us      | 261.402us | 96
# │││├── aten::as_strided               | 101.994us      | 101.994us | 96
# │││└── aten::empty_like               | 5.562us        | 12.818us  | 1
# ││├── 2                               |                |           |
# │││├── aten::hardtanh_                | 29.451us       | 179.478us | 1
# │││├── aten::clamp_                   | 7.956us        | 150.027us | 1
# │││└── aten::clamp                    | 142.071us      | 142.071us | 1
# │├── 1                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 4.259us        | 1.681ms   | 1
# │││││├── aten::convolution            | 4.394us        | 1.677ms   | 1
# │││││├── aten::_convolution           | 15.242us       | 1.672ms   | 1
# │││││├── aten::mkldnn_convolution     | 1.645ms        | 1.657ms   | 1
# │││││├── aten::empty                  | 8.512us        | 8.512us   | 1
# │││││└── aten::as_strided_            | 3.826us        | 3.826us   | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 17.332us       | 17.332us  | 1
# │││││├── aten::batch_norm             | 4.393us        | 2.178ms   | 1
# │││││├── aten::_batch_norm_impl_index | 7.207us        | 2.174ms   | 1
# │││││├── aten::empty                  | 9.904us        | 9.904us   | 4
# │││││├── aten::native_batch_norm      | 1.948ms        | 2.165ms   | 1
# │││││├── aten::select                 | 134.203us      | 204.636us | 96
# │││││├── aten::as_strided             | 70.433us       | 70.433us  | 96
# │││││└── aten::empty_like             | 3.987us        | 9.704us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 20.225us       | 137.892us | 1
# │││││├── aten::clamp_                 | 5.285us        | 117.667us | 1
# │││││└── aten::clamp                  | 112.382us      | 112.382us | 1
# │││├── 1                              |                |           |
# ││││├── aten::conv2d                  | 3.584us        | 693.241us | 1
# ││││├── aten::convolution             | 4.981us        | 689.657us | 1
# ││││├── aten::_convolution            | 18.301us       | 684.676us | 1
# ││││├── aten::_convolution_nogroup    | 12.819us       | 666.375us | 1
# ││││├── aten::_nnpack_available       | 1.520us        | 1.520us   | 1
# ││││├── aten::thnn_conv2d             | 8.564us        | 652.036us | 1
# ││││├── aten::thnn_conv2d_forward     | 73.261us       | 643.472us | 1
# ││││├── aten::empty                   | 4.301us        | 4.301us   | 3
# ││││├── aten::view                    | 10.450us       | 10.450us  | 5
# ││││├── aten::detach                  | 1.384us        | 1.384us   | 1
# ││││├── aten::resize_                 | 7.275us        | 7.275us   | 1
# ││││├── aten::select                  | 5.834us        | 8.524us   | 3
# ││││├── aten::as_strided              | 4.013us        | 4.013us   | 4
# ││││├── aten::unsqueeze               | 1.882us        | 3.205us   | 1
# ││││├── aten::reshape                 | 1.898us        | 3.296us   | 1
# ││││└── aten::mm                      | 533.174us      | 533.174us | 1
# │││├── 2                              |                |           |
# ││││├── aten::add                     | 15.232us       | 15.232us  | 1
# ││││├── aten::batch_norm              | 4.154us        | 1.181ms   | 1
# ││││├── aten::_batch_norm_impl_index  | 6.568us        | 1.177ms   | 1
# ││││├── aten::empty                   | 7.798us        | 7.798us   | 4
# ││││├── aten::native_batch_norm       | 1.072ms        | 1.169ms   | 1
# ││││├── aten::select                  | 55.696us       | 86.189us  | 48
# ││││├── aten::as_strided              | 30.493us       | 30.493us  | 48
# ││││└── aten::empty_like              | 3.697us        | 8.054us   | 1
# │├── 2                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 6.105us        | 2.523ms   | 1
# │││││├── aten::convolution            | 5.122us        | 2.517ms   | 1
# │││││├── aten::_convolution           | 15.380us       | 2.512ms   | 1
# │││││├── aten::_convolution_nogroup   | 9.690us        | 2.497ms   | 1
# │││││├── aten::_nnpack_available      | 2.316us        | 2.316us   | 1
# │││││├── aten::thnn_conv2d            | 7.056us        | 2.485ms   | 1
# │││││├── aten::thnn_conv2d_forward    | 114.013us      | 2.478ms   | 1
# │││││├── aten::empty                  | 5.504us        | 5.504us   | 3
# │││││├── aten::view                   | 15.155us       | 15.155us  | 5
# │││││├── aten::detach                 | 1.381us        | 1.381us   | 1
# │││││├── aten::resize_                | 12.468us       | 12.468us  | 1
# │││││├── aten::select                 | 9.225us        | 14.273us  | 3
# │││││├── aten::as_strided             | 6.554us        | 6.554us   | 4
# │││││├── aten::unsqueeze              | 2.433us        | 3.939us   | 1
# │││││├── aten::reshape                | 3.128us        | 5.701us   | 1
# │││││└── aten::mm                     | 2.308ms        | 2.308ms   | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 19.320us       | 19.320us  | 1
# │││││├── aten::batch_norm             | 5.876us        | 9.324ms   | 1
# │││││├── aten::_batch_norm_impl_index | 8.674us        | 9.319ms   | 1
# │││││├── aten::empty                  | 24.437us       | 24.437us  | 4
# │││││├── aten::native_batch_norm      | 8.027ms        | 9.308ms   | 1
# │││││├── aten::select                 | 712.120us      | 1.252ms   | 288
# │││││├── aten::as_strided             | 539.701us      | 539.701us | 288
# │││││└── aten::empty_like             | 6.974us        | 27.566us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 34.711us       | 563.278us | 1
# │││││├── aten::clamp_                 | 9.514us        | 528.567us | 1
# │││││└── aten::clamp                  | 519.053us      | 519.053us | 1
# │││├── 1                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 5.743us        | 18.590ms  | 1
# │││││├── aten::convolution            | 5.769us        | 18.584ms  | 1
# │││││├── aten::_convolution           | 377.093us      | 18.578ms  | 1
# │││││├── aten::narrow                 | 366.535us      | 2.326ms   | 192
# │││││├── aten::slice                  | 1.779ms        | 1.959ms   | 192
# │││││├── aten::as_strided             | 488.927us      | 488.927us | 576
# │││││├── aten::_convolution_nogroup   | 304.790us      | 15.437ms  | 96
# │││││├── aten::_nnpack_available      | 64.091us       | 64.091us  | 96
# │││││├── aten::thnn_conv2d            | 166.619us      | 15.068ms  | 96
# │││││├── aten::thnn_conv2d_forward    | 11.764ms       | 14.901ms  | 96
# │││││├── aten::empty                  | 342.265us      | 342.265us | 289
# │││││├── aten::view                   | 282.583us      | 282.583us | 192
# │││││├── aten::resize_                | 492.371us      | 492.371us | 193
# │││││├── aten::select                 | 477.523us      | 714.810us | 288
# │││││├── aten::unsqueeze              | 113.945us      | 184.748us | 96
# │││││├── aten::reshape                | 197.303us      | 334.110us | 96
# │││││├── aten::addmm_                 | 929.384us      | 929.384us | 96
# │││││├── aten::cat                    | 103.277us      | 438.853us | 1
# │││││└── aten::_cat                   | 329.653us      | 335.576us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 25.992us       | 25.992us  | 1
# │││││├── aten::batch_norm             | 6.312us        | 2.151ms   | 1
# │││││├── aten::_batch_norm_impl_index | 9.431us        | 2.145ms   | 1
# │││││├── aten::empty                  | 11.819us       | 11.819us  | 4
# │││││├── aten::native_batch_norm      | 1.636ms        | 2.134ms   | 1
# │││││├── aten::select                 | 259.631us      | 482.965us | 288
# │││││├── aten::as_strided             | 223.334us      | 223.334us | 288
# │││││└── aten::empty_like             | 4.808us        | 13.478us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 25.132us       | 170.833us | 1
# │││││├── aten::clamp_                 | 6.163us        | 145.701us | 1
# │││││└── aten::clamp                  | 139.538us      | 139.538us | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 3.868us        | 528.108us | 1
# ││││├── aten::convolution             | 4.213us        | 524.240us | 1
# ││││├── aten::_convolution            | 12.146us       | 520.027us | 1
# ││││├── aten::_convolution_nogroup    | 6.937us        | 507.881us | 1
# ││││├── aten::_nnpack_available       | 1.640us        | 1.640us   | 1
# ││││├── aten::thnn_conv2d             | 4.408us        | 499.304us | 1
# ││││├── aten::thnn_conv2d_forward     | 67.780us       | 494.896us | 1
# ││││├── aten::empty                   | 5.497us        | 5.497us   | 3
# ││││├── aten::view                    | 10.302us       | 10.302us  | 5
# ││││├── aten::detach                  | 1.699us        | 1.699us   | 1
# ││││├── aten::resize_                 | 6.604us        | 6.604us   | 1
# ││││├── aten::select                  | 9.545us        | 13.356us  | 3
# ││││├── aten::as_strided              | 5.030us        | 5.030us   | 4
# ││││├── aten::unsqueeze               | 2.710us        | 3.929us   | 1
# ││││├── aten::reshape                 | 2.355us        | 3.764us   | 1
# ││││└── aten::mm                      | 383.374us      | 383.374us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 16.236us       | 16.236us  | 1
# ││││├── aten::batch_norm              | 4.229us        | 629.411us | 1
# ││││├── aten::_batch_norm_impl_index  | 6.204us        | 625.182us | 1
# ││││├── aten::empty                   | 5.309us        | 5.309us   | 4
# ││││├── aten::native_batch_norm       | 492.798us      | 617.976us | 1
# ││││├── aten::select                  | 65.668us       | 117.840us | 72
# ││││├── aten::as_strided              | 52.172us       | 52.172us  | 72
# ││││└── aten::empty_like              | 3.031us        | 5.649us   | 1
# │├── 3                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 3.354us        | 814.876us | 1
# │││││├── aten::convolution            | 3.478us        | 811.522us | 1
# │││││├── aten::_convolution           | 9.745us        | 808.044us | 1
# │││││├── aten::_convolution_nogroup   | 5.969us        | 798.299us | 1
# │││││├── aten::_nnpack_available      | 2.024us        | 2.024us   | 1
# │││││├── aten::thnn_conv2d            | 3.326us        | 790.306us | 1
# │││││├── aten::thnn_conv2d_forward    | 50.498us       | 786.980us | 1
# │││││├── aten::empty                  | 3.091us        | 3.091us   | 3
# │││││├── aten::view                   | 6.612us        | 6.612us   | 5
# │││││├── aten::detach                 | 1.008us        | 1.008us   | 1
# │││││├── aten::resize_                | 10.093us       | 10.093us  | 1
# │││││├── aten::select                 | 4.256us        | 6.187us   | 3
# │││││├── aten::as_strided             | 2.621us        | 2.621us   | 4
# │││││├── aten::unsqueeze              | 1.289us        | 1.979us   | 1
# │││││├── aten::reshape                | 1.425us        | 2.320us   | 1
# │││││└── aten::mm                     | 706.087us      | 706.087us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 14.029us       | 14.029us  | 1
# │││││├── aten::batch_norm             | 3.619us        | 3.157ms   | 1
# │││││├── aten::_batch_norm_impl_index | 5.297us        | 3.153ms   | 1
# │││││├── aten::empty                  | 9.375us        | 9.375us   | 4
# │││││├── aten::native_batch_norm      | 2.477ms        | 3.147ms   | 1
# │││││├── aten::select                 | 371.704us      | 658.464us | 432
# │││││├── aten::as_strided             | 286.760us      | 286.760us | 432
# │││││└── aten::empty_like             | 3.090us        | 10.050us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 39.846us       | 303.037us | 1
# │││││├── aten::clamp_                 | 10.310us       | 263.191us | 1
# │││││└── aten::clamp                  | 252.881us      | 252.881us | 1
# │││├── 1                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 5.879us        | 21.526ms  | 1
# │││││├── aten::convolution            | 5.915us        | 21.520ms  | 1
# │││││├── aten::_convolution           | 519.945us      | 21.514ms  | 1
# │││││├── aten::narrow                 | 506.293us      | 2.710ms   | 288
# │││││├── aten::slice                  | 1.972ms        | 2.204ms   | 288
# │││││├── aten::as_strided             | 626.517us      | 626.517us | 864
# │││││├── aten::_convolution_nogroup   | 367.399us      | 17.778ms  | 144
# │││││├── aten::_nnpack_available      | 67.113us       | 67.113us  | 144
# │││││├── aten::thnn_conv2d            | 231.636us      | 17.343ms  | 144
# │││││├── aten::thnn_conv2d_forward    | 12.122ms       | 17.112ms  | 144
# │││││├── aten::empty                  | 339.432us      | 339.432us | 433
# │││││├── aten::view                   | 1.272ms        | 1.272ms   | 288
# │││││├── aten::resize_                | 866.719us      | 866.719us | 289
# │││││├── aten::select                 | 563.717us      | 848.765us | 432
# │││││├── aten::unsqueeze              | 187.203us      | 296.099us | 144
# │││││├── aten::reshape                | 234.684us      | 410.108us | 144
# │││││├── aten::addmm_                 | 1.137ms        | 1.137ms   | 144
# │││││├── aten::cat                    | 100.747us      | 506.107us | 1
# │││││└── aten::_cat                   | 400.284us      | 405.360us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 25.860us       | 25.860us  | 1
# │││││├── aten::batch_norm             | 6.961us        | 3.208ms   | 1
# │││││├── aten::_batch_norm_impl_index | 9.790us        | 3.201ms   | 1
# │││││├── aten::empty                  | 14.888us       | 14.888us  | 4
# │││││├── aten::native_batch_norm      | 2.484ms        | 3.190ms   | 1
# │││││├── aten::select                 | 386.245us      | 687.316us | 432
# │││││├── aten::as_strided             | 301.071us      | 301.071us | 432
# │││││└── aten::empty_like             | 5.213us        | 16.774us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 34.197us       | 257.843us | 1
# │││││├── aten::clamp_                 | 8.744us        | 223.646us | 1
# │││││└── aten::clamp                  | 214.902us      | 214.902us | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 5.275us        | 685.581us | 1
# ││││├── aten::convolution             | 4.195us        | 680.306us | 1
# ││││├── aten::_convolution            | 12.568us       | 676.111us | 1
# ││││├── aten::_convolution_nogroup    | 7.718us        | 663.543us | 1
# ││││├── aten::_nnpack_available       | 1.592us        | 1.592us   | 1
# ││││├── aten::thnn_conv2d             | 4.274us        | 654.233us | 1
# ││││├── aten::thnn_conv2d_forward     | 63.326us       | 649.959us | 1
# ││││├── aten::empty                   | 4.851us        | 4.851us   | 3
# ││││├── aten::view                    | 9.803us        | 9.803us   | 5
# ││││├── aten::detach                  | 1.114us        | 1.114us   | 1
# ││││├── aten::resize_                 | 6.795us        | 6.795us   | 1
# ││││├── aten::select                  | 6.718us        | 9.334us   | 3
# ││││├── aten::as_strided              | 3.537us        | 3.537us   | 4
# ││││├── aten::unsqueeze               | 1.604us        | 2.525us   | 1
# ││││├── aten::reshape                 | 1.621us        | 2.489us   | 1
# ││││└── aten::mm                      | 550.590us      | 550.590us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 17.243us       | 17.243us  | 1
# ││││├── aten::batch_norm              | 4.033us        | 589.197us | 1
# ││││├── aten::_batch_norm_impl_index  | 6.322us        | 585.164us | 1
# ││││├── aten::empty                   | 5.272us        | 5.272us   | 4
# ││││├── aten::native_batch_norm       | 462.052us      | 577.928us | 1
# ││││├── aten::select                  | 63.867us       | 108.451us | 72
# ││││├── aten::as_strided              | 44.584us       | 44.584us  | 72
# ││││└── aten::empty_like              | 3.067us        | 5.729us   | 1
# │├── 4                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 3.981us        | 743.273us | 1
# │││││├── aten::convolution            | 3.238us        | 739.292us | 1
# │││││├── aten::_convolution           | 9.242us        | 736.054us | 1
# │││││├── aten::_convolution_nogroup   | 5.912us        | 726.812us | 1
# │││││├── aten::_nnpack_available      | 1.288us        | 1.288us   | 1
# │││││├── aten::thnn_conv2d            | 3.856us        | 719.612us | 1
# │││││├── aten::thnn_conv2d_forward    | 54.206us       | 715.756us | 1
# │││││├── aten::empty                  | 2.952us        | 2.952us   | 3
# │││││├── aten::view                   | 6.961us        | 6.961us   | 5
# │││││├── aten::detach                 | 0.763us        | 0.763us   | 1
# │││││├── aten::resize_                | 8.970us        | 8.970us   | 1
# │││││├── aten::select                 | 4.781us        | 6.752us   | 3
# │││││├── aten::as_strided             | 2.676us        | 2.676us   | 4
# │││││├── aten::unsqueeze              | 1.406us        | 2.111us   | 1
# │││││├── aten::reshape                | 1.508us        | 2.488us   | 1
# │││││└── aten::mm                     | 631.533us      | 631.533us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 10.727us       | 10.727us  | 1
# │││││├── aten::batch_norm             | 4.427us        | 3.295ms   | 1
# │││││├── aten::_batch_norm_impl_index | 5.325us        | 3.291ms   | 1
# │││││├── aten::empty                  | 8.116us        | 8.116us   | 4
# │││││├── aten::native_batch_norm      | 2.573ms        | 3.285ms   | 1
# │││││├── aten::select                 | 398.938us      | 701.261us | 432
# │││││├── aten::as_strided             | 302.323us      | 302.323us | 432
# │││││└── aten::empty_like             | 3.201us        | 8.804us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 34.108us       | 263.922us | 1
# │││││├── aten::clamp_                 | 7.179us        | 229.814us | 1
# │││││└── aten::clamp                  | 222.635us      | 222.635us | 1
# │││├── 1                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 5.952us        | 13.804ms  | 1
# │││││├── aten::convolution            | 4.691us        | 13.798ms  | 1
# │││││├── aten::_convolution           | 386.176us      | 13.793ms  | 1
# │││││├── aten::narrow                 | 427.498us      | 2.406ms   | 288
# │││││├── aten::slice                  | 1.788ms        | 1.979ms   | 288
# │││││├── aten::as_strided             | 496.908us      | 496.908us | 864
# │││││├── aten::_convolution_nogroup   | 296.338us      | 10.773ms  | 144
# │││││├── aten::_nnpack_available      | 60.654us       | 60.654us  | 144
# │││││├── aten::thnn_conv2d            | 195.718us      | 10.416ms  | 144
# │││││├── aten::thnn_conv2d_forward    | 6.639ms        | 10.220ms  | 144
# │││││├── aten::empty                  | 285.869us      | 285.869us | 433
# │││││├── aten::view                   | 1.132ms        | 1.132ms   | 288
# │││││├── aten::resize_                | 606.161us      | 606.161us | 289
# │││││├── aten::select                 | 541.837us      | 768.286us | 432
# │││││├── aten::unsqueeze              | 148.384us      | 228.003us | 144
# │││││├── aten::reshape                | 173.459us      | 287.419us | 144
# │││││├── aten::addmm_                 | 391.188us      | 391.188us | 144
# │││││├── aten::cat                    | 103.734us      | 227.436us | 1
# │││││└── aten::_cat                   | 120.329us      | 123.702us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 25.937us       | 25.937us  | 1
# │││││├── aten::batch_norm             | 6.210us        | 1.719ms   | 1
# │││││├── aten::_batch_norm_impl_index | 9.380us        | 1.713ms   | 1
# │││││├── aten::empty                  | 7.485us        | 7.485us   | 4
# │││││├── aten::native_batch_norm      | 1.004ms        | 1.702ms   | 1
# │││││├── aten::select                 | 376.412us      | 688.647us | 432
# │││││├── aten::as_strided             | 312.235us      | 312.235us | 432
# │││││└── aten::empty_like             | 3.696us        | 7.965us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 33.527us       | 108.613us | 1
# │││││├── aten::clamp_                 | 5.339us        | 75.086us  | 1
# │││││└── aten::clamp                  | 69.747us       | 69.747us  | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 3.933us        | 385.739us | 1
# ││││├── aten::convolution             | 4.637us        | 381.806us | 1
# ││││├── aten::_convolution            | 12.142us       | 377.169us | 1
# ││││├── aten::_convolution_nogroup    | 7.699us        | 365.027us | 1
# ││││├── aten::_nnpack_available       | 1.286us        | 1.286us   | 1
# ││││├── aten::thnn_conv2d             | 4.058us        | 356.042us | 1
# ││││├── aten::thnn_conv2d_forward     | 58.094us       | 351.984us | 1
# ││││├── aten::empty                   | 4.761us        | 4.761us   | 3
# ││││├── aten::view                    | 8.783us        | 8.783us   | 5
# ││││├── aten::detach                  | 1.363us        | 1.363us   | 1
# ││││├── aten::resize_                 | 77.535us       | 77.535us  | 1
# ││││├── aten::select                  | 7.066us        | 9.869us   | 3
# ││││├── aten::as_strided              | 3.470us        | 3.470us   | 4
# ││││├── aten::unsqueeze               | 1.342us        | 2.009us   | 1
# ││││├── aten::reshape                 | 1.499us        | 2.399us   | 1
# ││││└── aten::mm                      | 188.071us      | 188.071us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 15.238us       | 15.238us  | 1
# ││││├── aten::batch_norm              | 4.035us        | 736.643us | 1
# ││││├── aten::_batch_norm_impl_index  | 5.813us        | 732.608us | 1
# ││││├── aten::empty                   | 37.440us       | 37.440us  | 4
# ││││├── aten::native_batch_norm       | 556.439us      | 725.965us | 1
# ││││├── aten::select                  | 86.649us       | 129.728us | 96
# ││││├── aten::as_strided              | 43.079us       | 43.079us  | 96
# ││││└── aten::empty_like              | 3.188us        | 38.257us  | 1
# │├── 5                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 3.065us        | 324.605us | 1
# │││││├── aten::convolution            | 2.296us        | 321.540us | 1
# │││││├── aten::_convolution           | 6.666us        | 319.244us | 1
# │││││├── aten::_convolution_nogroup   | 4.249us        | 312.578us | 1
# │││││├── aten::_nnpack_available      | 1.660us        | 1.660us   | 1
# │││││├── aten::thnn_conv2d            | 2.378us        | 306.669us | 1
# │││││├── aten::thnn_conv2d_forward    | 37.880us       | 304.291us | 1
# │││││├── aten::empty                  | 2.613us        | 2.613us   | 3
# │││││├── aten::view                   | 5.536us        | 5.536us   | 5
# │││││├── aten::detach                 | 0.706us        | 0.706us   | 1
# │││││├── aten::resize_                | 4.015us        | 4.015us   | 1
# │││││├── aten::select                 | 3.890us        | 5.522us   | 3
# │││││├── aten::as_strided             | 2.266us        | 2.266us   | 4
# │││││├── aten::unsqueeze              | 1.183us        | 1.817us   | 1
# │││││├── aten::reshape                | 1.152us        | 1.812us   | 1
# │││││└── aten::mm                     | 245.050us      | 245.050us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 10.930us       | 10.930us  | 1
# │││││├── aten::batch_norm             | 3.594us        | 2.284ms   | 1
# │││││├── aten::_batch_norm_impl_index | 4.215us        | 2.280ms   | 1
# │││││├── aten::empty                  | 5.008us        | 5.008us   | 4
# │││││├── aten::native_batch_norm      | 1.159ms        | 2.275ms   | 1
# │││││├── aten::select                 | 531.362us      | 1.110ms   | 576
# │││││├── aten::as_strided             | 578.505us      | 578.505us | 576
# │││││└── aten::empty_like             | 2.644us        | 5.597us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 26.179us       | 143.722us | 1
# │││││├── aten::clamp_                 | 5.628us        | 117.543us | 1
# │││││└── aten::clamp                  | 111.915us      | 111.915us | 1
# │││├── 1                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 3.787us        | 14.171ms  | 1
# │││││├── aten::convolution            | 4.623us        | 14.167ms  | 1
# │││││├── aten::_convolution           | 486.546us      | 14.162ms  | 1
# │││││├── aten::narrow                 | 524.318us      | 2.777ms   | 384
# │││││├── aten::slice                  | 2.010ms        | 2.253ms   | 384
# │││││├── aten::as_strided             | 657.346us      | 657.346us | 1152
# │││││├── aten::_convolution_nogroup   | 389.832us      | 10.582ms  | 192
# │││││├── aten::_nnpack_available      | 71.687us       | 71.687us  | 192
# │││││├── aten::thnn_conv2d            | 239.581us      | 10.121ms  | 192
# │││││├── aten::thnn_conv2d_forward    | 5.795ms        | 9.881ms   | 192
# │││││├── aten::empty                  | 376.757us      | 376.757us | 577
# │││││├── aten::view                   | 1.121ms        | 1.121ms   | 384
# │││││├── aten::resize_                | 536.669us      | 536.669us | 385
# │││││├── aten::select                 | 662.068us      | 974.411us | 576
# │││││├── aten::unsqueeze              | 206.729us      | 309.141us | 192
# │││││├── aten::reshape                | 230.603us      | 378.138us | 192
# │││││├── aten::addmm_                 | 540.437us      | 540.437us | 192
# │││││├── aten::cat                    | 109.610us      | 316.271us | 1
# │││││└── aten::_cat                   | 203.500us      | 206.661us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 25.575us       | 25.575us  | 1
# │││││├── aten::batch_norm             | 5.926us        | 2.409ms   | 1
# │││││├── aten::_batch_norm_impl_index | 9.471us        | 2.403ms   | 1
# │││││├── aten::empty                  | 7.359us        | 7.359us   | 4
# │││││├── aten::native_batch_norm      | 1.270ms        | 2.393ms   | 1
# │││││├── aten::select                 | 531.332us      | 1.112ms   | 576
# │││││├── aten::as_strided             | 580.713us      | 580.713us | 576
# │││││└── aten::empty_like             | 4.412us        | 8.762us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 27.044us       | 115.135us | 1
# │││││├── aten::clamp_                 | 5.907us        | 88.091us  | 1
# │││││└── aten::clamp                  | 82.184us       | 82.184us  | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 4.133us        | 330.160us | 1
# ││││├── aten::convolution             | 4.242us        | 326.027us | 1
# ││││├── aten::_convolution            | 11.415us       | 321.785us | 1
# ││││├── aten::_convolution_nogroup    | 7.256us        | 310.370us | 1
# ││││├── aten::_nnpack_available       | 1.377us        | 1.377us   | 1
# ││││├── aten::thnn_conv2d             | 3.651us        | 301.737us | 1
# ││││├── aten::thnn_conv2d_forward     | 55.216us       | 298.086us | 1
# ││││├── aten::empty                   | 4.515us        | 4.515us   | 3
# ││││├── aten::view                    | 8.928us        | 8.928us   | 5
# ││││├── aten::detach                  | 1.051us        | 1.051us   | 1
# ││││├── aten::resize_                 | 4.477us        | 4.477us   | 1
# ││││├── aten::select                  | 7.091us        | 9.537us   | 3
# ││││├── aten::as_strided              | 3.036us        | 3.036us   | 4
# ││││├── aten::unsqueeze               | 1.299us        | 1.889us   | 1
# ││││├── aten::reshape                 | 1.525us        | 2.262us   | 1
# ││││└── aten::mm                      | 210.948us      | 210.948us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 15.318us       | 15.318us  | 1
# ││││├── aten::batch_norm              | 3.951us        | 506.380us | 1
# ││││├── aten::_batch_norm_impl_index  | 5.870us        | 502.429us | 1
# ││││├── aten::empty                   | 30.153us       | 30.153us  | 4
# ││││├── aten::native_batch_norm       | 340.876us      | 495.849us | 1
# ││││├── aten::select                  | 82.617us       | 122.870us | 96
# ││││├── aten::as_strided              | 40.253us       | 40.253us  | 96
# ││││└── aten::empty_like              | 2.660us        | 30.398us  | 1
# │├── 6                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 2.721us        | 344.061us | 1
# │││││├── aten::convolution            | 2.368us        | 341.340us | 1
# │││││├── aten::_convolution           | 7.618us        | 338.972us | 1
# │││││├── aten::_convolution_nogroup   | 4.846us        | 331.354us | 1
# │││││├── aten::_nnpack_available      | 1.043us        | 1.043us   | 1
# │││││├── aten::thnn_conv2d            | 2.906us        | 325.465us | 1
# │││││├── aten::thnn_conv2d_forward    | 41.341us       | 322.559us | 1
# │││││├── aten::empty                  | 2.182us        | 2.182us   | 3
# │││││├── aten::view                   | 6.456us        | 6.456us   | 5
# │││││├── aten::detach                 | 0.755us        | 0.755us   | 1
# │││││├── aten::resize_                | 4.504us        | 4.504us   | 1
# │││││├── aten::select                 | 4.522us        | 6.567us   | 3
# │││││├── aten::as_strided             | 2.706us        | 2.706us   | 4
# │││││├── aten::unsqueeze              | 1.348us        | 2.009us   | 1
# │││││├── aten::reshape                | 1.376us        | 2.125us   | 1
# │││││└── aten::mm                     | 257.369us      | 257.369us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 12.648us       | 12.648us  | 1
# │││││├── aten::batch_norm             | 3.867us        | 3.336ms   | 1
# │││││├── aten::_batch_norm_impl_index | 6.802us        | 3.332ms   | 1
# │││││├── aten::empty                  | 9.165us        | 9.165us   | 4
# │││││├── aten::native_batch_norm      | 1.706ms        | 3.324ms   | 1
# │││││├── aten::select                 | 815.484us      | 1.606ms   | 576
# │││││├── aten::as_strided             | 790.134us      | 790.134us | 576
# │││││└── aten::empty_like             | 4.462us        | 9.815us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 29.297us       | 127.861us | 1
# │││││├── aten::clamp_                 | 5.875us        | 98.564us  | 1
# │││││└── aten::clamp                  | 92.689us       | 92.689us  | 1
# │││├── 1                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 4.265us        | 17.483ms  | 1
# │││││├── aten::convolution            | 4.966us        | 17.478ms  | 1
# │││││├── aten::_convolution           | 684.983us      | 17.474ms  | 1
# │││││├── aten::narrow                 | 619.952us      | 3.399ms   | 384
# │││││├── aten::slice                  | 2.493ms        | 2.780ms   | 384
# │││││├── aten::as_strided             | 787.726us      | 787.726us | 1152
# │││││├── aten::_convolution_nogroup   | 529.667us      | 13.104ms  | 192
# │││││├── aten::_nnpack_available      | 103.094us      | 103.094us | 192
# │││││├── aten::thnn_conv2d            | 292.070us      | 12.472ms  | 192
# │││││├── aten::thnn_conv2d_forward    | 7.189ms        | 12.180ms  | 192
# │││││├── aten::empty                  | 435.516us      | 435.516us | 577
# │││││├── aten::view                   | 1.270ms        | 1.270ms   | 384
# │││││├── aten::resize_                | 825.702us      | 825.702us | 385
# │││││├── aten::select                 | 810.178us      | 1.180ms   | 576
# │││││├── aten::unsqueeze              | 255.131us      | 386.752us | 192
# │││││├── aten::reshape                | 290.876us      | 520.564us | 192
# │││││├── aten::addmm_                 | 605.281us      | 605.281us | 192
# │││││├── aten::cat                    | 121.894us      | 284.573us | 1
# │││││└── aten::_cat                   | 159.886us      | 162.679us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 24.940us       | 24.940us  | 1
# │││││├── aten::batch_norm             | 5.681us        | 2.558ms   | 1
# │││││├── aten::_batch_norm_impl_index | 8.599us        | 2.552ms   | 1
# │││││├── aten::empty                  | 7.341us        | 7.341us   | 4
# │││││├── aten::native_batch_norm      | 1.385ms        | 2.542ms   | 1
# │││││├── aten::select                 | 548.349us      | 1.147ms   | 576
# │││││├── aten::as_strided             | 598.465us      | 598.465us | 576
# │││││└── aten::empty_like             | 4.665us        | 8.358us   | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 28.579us       | 121.204us | 1
# │││││├── aten::clamp_                 | 5.850us        | 92.625us  | 1
# │││││└── aten::clamp                  | 86.775us       | 86.775us  | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 4.597us        | 310.579us | 1
# ││││├── aten::convolution             | 4.018us        | 305.982us | 1
# ││││├── aten::_convolution            | 11.859us       | 301.964us | 1
# ││││├── aten::_convolution_nogroup    | 7.830us        | 290.105us | 1
# ││││├── aten::_nnpack_available       | 1.440us        | 1.440us   | 1
# ││││├── aten::thnn_conv2d             | 3.905us        | 280.835us | 1
# ││││├── aten::thnn_conv2d_forward     | 59.986us       | 276.930us | 1
# ││││├── aten::empty                   | 4.790us        | 4.790us   | 3
# ││││├── aten::view                    | 9.018us        | 9.018us   | 5
# ││││├── aten::detach                  | 1.323us        | 1.323us   | 1
# ││││├── aten::resize_                 | 5.166us        | 5.166us   | 1
# ││││├── aten::select                  | 7.069us        | 10.047us  | 3
# ││││├── aten::as_strided              | 3.758us        | 3.758us   | 4
# ││││├── aten::unsqueeze               | 1.387us        | 2.167us   | 1
# ││││├── aten::reshape                 | 1.526us        | 2.296us   | 1
# ││││└── aten::mm                      | 182.907us      | 182.907us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 15.713us       | 15.713us  | 1
# ││││├── aten::batch_norm              | 4.515us        | 386.402us | 1
# ││││├── aten::_batch_norm_impl_index  | 5.814us        | 381.887us | 1
# ││││├── aten::empty                   | 17.984us       | 17.984us  | 4
# ││││├── aten::native_batch_norm       | 225.749us      | 375.176us | 1
# ││││├── aten::select                  | 85.794us       | 129.497us | 96
# ││││├── aten::as_strided              | 43.703us       | 43.703us  | 96
# ││││└── aten::empty_like              | 2.843us        | 18.279us  | 1
# │├── 7                                |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 2.706us        | 334.355us | 1
# │││││├── aten::convolution            | 2.817us        | 331.649us | 1
# │││││├── aten::_convolution           | 7.656us        | 328.832us | 1
# │││││├── aten::_convolution_nogroup   | 5.031us        | 321.176us | 1
# │││││├── aten::_nnpack_available      | 1.245us        | 1.245us   | 1
# │││││├── aten::thnn_conv2d            | 3.467us        | 314.900us | 1
# │││││├── aten::thnn_conv2d_forward    | 42.482us       | 311.433us | 1
# │││││├── aten::empty                  | 2.670us        | 2.670us   | 3
# │││││├── aten::view                   | 6.717us        | 6.717us   | 5
# │││││├── aten::detach                 | 0.773us        | 0.773us   | 1
# │││││├── aten::resize_                | 4.944us        | 4.944us   | 1
# │││││├── aten::select                 | 4.789us        | 7.013us   | 3
# │││││├── aten::as_strided             | 13.398us       | 13.398us  | 4
# │││││├── aten::unsqueeze              | 1.537us        | 12.711us  | 1
# │││││├── aten::reshape                | 1.475us        | 2.332us   | 1
# │││││└── aten::mm                     | 232.648us      | 232.648us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 10.645us       | 10.645us  | 1
# │││││├── aten::batch_norm             | 3.524us        | 2.371ms   | 1
# │││││├── aten::_batch_norm_impl_index | 5.218us        | 2.367ms   | 1
# │││││├── aten::empty                  | 6.250us        | 6.250us   | 4
# ...
# │││││├── aten::unsqueeze              | 989.795us      | 1.613ms   | 960
# │││││├── aten::reshape                | 1.156ms        | 1.853ms   | 960
# │││││├── aten::addmm_                 | 1.608ms        | 1.608ms   | 960
# │││││├── aten::cat                    | 564.734us      | 773.466us | 1
# │││││└── aten::_cat                   | 204.536us      | 208.732us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 26.427us       | 26.427us  | 1
# │││││├── aten::batch_norm             | 7.198us        | 9.383ms   | 1
# │││││├── aten::_batch_norm_impl_index | 10.195us       | 9.376ms   | 1
# │││││├── aten::empty                  | 11.529us       | 11.529us  | 4
# │││││├── aten::native_batch_norm      | 3.617ms        | 9.365ms   | 1
# │││││├── aten::select                 | 2.760ms        | 5.733ms   | 2880
# │││││├── aten::as_strided             | 2.973ms        | 2.973ms   | 2880
# │││││└── aten::empty_like             | 4.958us        | 12.526us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 40.637us       | 87.462us  | 1
# │││││├── aten::clamp_                 | 5.958us        | 46.825us  | 1
# │││││└── aten::clamp                  | 40.867us       | 40.867us  | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 4.531us        | 598.623us | 1
# ││││├── aten::convolution             | 5.573us        | 594.092us | 1
# ││││├── aten::_convolution            | 11.489us       | 588.519us | 1
# ││││├── aten::_convolution_nogroup    | 7.188us        | 577.030us | 1
# ││││├── aten::_nnpack_available       | 1.744us        | 1.744us   | 1
# ││││├── aten::thnn_conv2d             | 4.282us        | 568.098us | 1
# ││││├── aten::thnn_conv2d_forward     | 66.435us       | 563.816us | 1
# ││││├── aten::empty                   | 5.316us        | 5.316us   | 3
# ││││├── aten::view                    | 8.976us        | 8.976us   | 5
# ││││├── aten::detach                  | 1.305us        | 1.305us   | 1
# ││││├── aten::resize_                 | 5.031us        | 5.031us   | 1
# ││││├── aten::select                  | 7.647us        | 10.616us  | 3
# ││││├── aten::as_strided              | 3.853us        | 3.853us   | 4
# ││││├── aten::unsqueeze               | 1.519us        | 2.403us   | 1
# ││││├── aten::reshape                 | 1.587us        | 2.433us   | 1
# ││││└── aten::mm                      | 462.147us      | 462.147us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 19.041us       | 19.041us  | 1
# ││││├── aten::batch_norm              | 4.679us        | 1.433ms   | 1
# ││││├── aten::_batch_norm_impl_index  | 7.251us        | 1.428ms   | 1
# ││││├── aten::empty                   | 8.715us        | 8.715us   | 4
# ││││├── aten::native_batch_norm       | 617.854us      | 1.420ms   | 1
# ││││├── aten::select                  | 455.074us      | 790.994us | 480
# ││││├── aten::as_strided              | 335.920us      | 335.920us | 480
# ││││└── aten::empty_like              | 3.411us        | 9.189us   | 1
# │├── 17                               |                |           |
# ││├── conv                            |                |           |
# │││├── 0                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 4.592us        | 546.079us | 1
# │││││├── aten::convolution            | 4.779us        | 541.487us | 1
# │││││├── aten::_convolution           | 11.559us       | 536.708us | 1
# │││││├── aten::_convolution_nogroup   | 6.501us        | 525.149us | 1
# │││││├── aten::_nnpack_available      | 2.237us        | 2.237us   | 1
# │││││├── aten::thnn_conv2d            | 4.527us        | 516.411us | 1
# │││││├── aten::thnn_conv2d_forward    | 59.334us       | 511.884us | 1
# │││││├── aten::empty                  | 2.725us        | 2.725us   | 3
# │││││├── aten::view                   | 8.496us        | 8.496us   | 5
# │││││├── aten::detach                 | 1.054us        | 1.054us   | 1
# │││││├── aten::resize_                | 5.328us        | 5.328us   | 1
# │││││├── aten::select                 | 6.100us        | 8.497us   | 3
# │││││├── aten::as_strided             | 3.037us        | 3.037us   | 4
# │││││├── aten::unsqueeze              | 1.213us        | 1.853us   | 1
# │││││├── aten::reshape                | 1.524us        | 2.366us   | 1
# │││││└── aten::mm                     | 423.073us      | 423.073us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 13.532us       | 13.532us  | 1
# │││││├── aten::batch_norm             | 5.057us        | 8.409ms   | 1
# │││││├── aten::_batch_norm_impl_index | 8.420us        | 8.404ms   | 1
# │││││├── aten::empty                  | 8.850us        | 8.850us   | 4
# │││││├── aten::native_batch_norm      | 2.990ms        | 8.394ms   | 1
# │││││├── aten::select                 | 2.437ms        | 5.387ms   | 2880
# │││││├── aten::as_strided             | 2.950ms        | 2.950ms   | 2880
# │││││└── aten::empty_like             | 10.052us       | 15.960us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 38.409us       | 100.015us | 1
# │││││├── aten::clamp_                 | 6.341us        | 61.606us  | 1
# │││││└── aten::clamp                  | 55.265us       | 55.265us  | 1
# │││├── 1                              |                |           |
# ││││├── 0                             |                |           |
# │││││├── aten::conv2d                 | 4.691us        | 57.155ms  | 1
# │││││├── aten::convolution            | 6.812us        | 57.150ms  | 1
# │││││├── aten::_convolution           | 2.435ms        | 57.143ms  | 1
# │││││├── aten::narrow                 | 3.822ms        | 15.908ms  | 1920
# │││││├── aten::slice                  | 10.944ms       | 12.087ms  | 1920
# │││││├── aten::as_strided             | 3.064ms        | 3.064ms   | 5760
# │││││├── aten::_convolution_nogroup   | 1.824ms        | 38.027ms  | 960
# │││││├── aten::_nnpack_available      | 347.069us      | 347.069us | 960
# │││││├── aten::thnn_conv2d            | 1.167ms        | 35.856ms  | 960
# │││││├── aten::thnn_conv2d_forward    | 20.267ms       | 34.689ms  | 960
# │││││├── aten::empty                  | 1.729ms        | 1.729ms   | 2881
# │││││├── aten::view                   | 2.545ms        | 2.545ms   | 1920
# │││││├── aten::resize_                | 1.321ms        | 1.321ms   | 1921
# │││││├── aten::select                 | 3.348ms        | 4.779ms   | 2880
# │││││├── aten::unsqueeze              | 965.003us      | 1.455ms   | 960
# │││││├── aten::reshape                | 1.099ms        | 1.943ms   | 960
# │││││├── aten::addmm_                 | 1.499ms        | 1.499ms   | 960
# │││││├── aten::cat                    | 579.532us      | 772.737us | 1
# │││││└── aten::_cat                   | 186.928us      | 193.205us | 1
# ││││├── 1                             |                |           |
# │││││├── aten::add                    | 27.906us       | 27.906us  | 1
# │││││├── aten::batch_norm             | 6.646us        | 8.407ms   | 1
# │││││├── aten::_batch_norm_impl_index | 10.446us       | 8.400ms   | 1
# │││││├── aten::empty                  | 9.950us        | 9.950us   | 4
# │││││├── aten::native_batch_norm      | 3.032ms        | 8.388ms   | 1
# │││││├── aten::select                 | 2.471ms        | 5.343ms   | 2880
# │││││├── aten::as_strided             | 2.872ms        | 2.872ms   | 2880
# │││││└── aten::empty_like             | 4.765us        | 10.834us  | 1
# ││││├── 2                             |                |           |
# │││││├── aten::hardtanh_              | 911.747us      | 1.002ms   | 1
# │││││├── aten::clamp_                 | 10.188us       | 90.712us  | 1
# │││││└── aten::clamp                  | 80.524us       | 80.524us  | 1
# │││├── 2                              |                |           |
# ││││├── aten::conv2d                  | 4.936us        | 864.646us | 1
# ││││├── aten::convolution             | 4.740us        | 859.710us | 1
# ││││├── aten::_convolution            | 12.441us       | 854.970us | 1
# ││││├── aten::_convolution_nogroup    | 6.986us        | 842.529us | 1
# ││││├── aten::_nnpack_available       | 1.591us        | 1.591us   | 1
# ││││├── aten::thnn_conv2d             | 3.694us        | 833.952us | 1
# ││││├── aten::thnn_conv2d_forward     | 64.359us       | 830.258us | 1
# ││││├── aten::empty                   | 4.693us        | 4.693us   | 3
# ││││├── aten::view                    | 7.681us        | 7.681us   | 5
# ││││├── aten::detach                  | 1.060us        | 1.060us   | 1
# ││││├── aten::resize_                 | 7.082us        | 7.082us   | 1
# ││││├── aten::select                  | 6.139us        | 8.499us   | 3
# ││││├── aten::as_strided              | 3.043us        | 3.043us   | 4
# ││││├── aten::unsqueeze               | 1.725us        | 2.408us   | 1
# ││││├── aten::reshape                 | 1.331us        | 1.996us   | 1
# ││││└── aten::mm                      | 733.145us      | 733.145us | 1
# │││├── 3                              |                |           |
# ││││├── aten::add                     | 22.356us       | 22.356us  | 1
# ││││├── aten::batch_norm              | 5.763us        | 3.034ms   | 1
# ││││├── aten::_batch_norm_impl_index  | 8.889us        | 3.028ms   | 1
# ││││├── aten::empty                   | 8.520us        | 8.520us   | 4
# ││││├── aten::native_batch_norm       | 1.193ms        | 3.018ms   | 1
# ││││├── aten::select                  | 958.181us      | 1.813ms   | 960
# ││││├── aten::as_strided              | 855.116us      | 855.116us | 960
# ││││└── aten::empty_like              | 4.078us        | 8.747us   | 1
# │├── 18                               |                |           |
# ││├── 0                               |                |           |
# │││├── aten::conv2d                   | 5.921us        | 1.163ms   | 1
# │││├── aten::convolution              | 4.447us        | 1.157ms   | 1
# │││├── aten::_convolution             | 13.357us       | 1.153ms   | 1
# │││├── aten::_convolution_nogroup     | 7.333us        | 1.139ms   | 1
# │││├── aten::_nnpack_available        | 2.042us        | 2.042us   | 1
# │││├── aten::thnn_conv2d              | 3.802us        | 1.130ms   | 1
# │││├── aten::thnn_conv2d_forward      | 76.251us       | 1.126ms   | 1
# │││├── aten::empty                    | 4.810us        | 4.810us   | 3
# │││├── aten::view                     | 8.827us        | 8.827us   | 5
# │││├── aten::detach                   | 1.332us        | 1.332us   | 1
# │││├── aten::resize_                  | 8.259us        | 8.259us   | 1
# │││├── aten::select                   | 6.700us        | 9.037us   | 3
# │││├── aten::as_strided               | 3.261us        | 3.261us   | 4
# │││├── aten::unsqueeze                | 1.304us        | 2.228us   | 1
# │││├── aten::reshape                  | 1.741us        | 2.717us   | 1
# │││└── aten::mm                       | 1.014ms        | 1.014ms   | 1
# ││├── 1                               |                |           |
# │││├── aten::add                      | 21.424us       | 21.424us  | 1
# │││├── aten::batch_norm               | 5.807us        | 10.163ms  | 1
# │││├── aten::_batch_norm_impl_index   | 7.807us        | 10.158ms  | 1
# │││├── aten::empty                    | 9.942us        | 9.942us   | 4
# │││├── aten::native_batch_norm        | 3.779ms        | 10.148ms  | 1
# │││├── aten::select                   | 3.194ms        | 6.357ms   | 3840
# │││├── aten::as_strided               | 3.163ms        | 3.163ms   | 3840
# │││└── aten::empty_like               | 4.294us        | 9.746us   | 1
# ││├── 2                               |                |           |
# │││├── aten::hardtanh_                | 32.123us       | 118.231us | 1
# │││├── aten::clamp_                   | 7.232us        | 86.108us  | 1
# │││└── aten::clamp                    | 78.876us       | 78.876us  | 1
# └── classifier                        |                |           |
#  ├── 0                                |                |           |
#  │├── aten::dropout                   | 20.267us       | 128.200us | 1
#  │├── aten::empty_like                | 4.436us        | 10.957us  | 1
#  │├── aten::empty                     | 8.918us        | 8.918us   | 3
#  │├── aten::bernoulli_                | 42.186us       | 43.513us  | 1
#  │├── aten::div_                      | 16.283us       | 31.863us  | 1
#  │├── aten::to                        | 6.218us        | 15.580us  | 1
#  │├── aten::empty_strided             | 2.861us        | 2.861us   | 1
#  │├── aten::copy_                     | 6.501us        | 6.501us   | 1
#  │└── aten::mul                       | 20.530us       | 21.600us  | 1
#  └── 1                                |                |           |
#   ├── aten::linear                    | 12.452us       | 962.552us | 1
#   ├── aten::t                         | 15.818us       | 23.937us  | 1
#   ├── aten::transpose                 | 3.130us        | 8.119us   | 1
#   ├── aten::as_strided                | 6.083us        | 6.083us   | 2
#   ├── aten::addmm                     | 900.397us      | 926.163us | 1
#   ├── aten::empty                     | 1.544us        | 1.544us   | 1
#   ├── aten::expand                    | 3.347us        | 4.441us   | 1
#   └── aten::copy_                     | 19.781us       | 19.781us  | 1

# %%
# print(prof.key_averages().table(sort_by="cpu_time_total"))

# %%
import torch
import torchvision
# !pip install torchprof
import torchprof
import torchvision.models as models
#from torch.profiler import profile, record_function, ProfilerActivity
#from torchsummary import summary
